# %%
from alpha_vantage.timeseries import TimeSeries

# %%
apikey = 'JL9GIGT0KVN581XQ'

# %%
ts = TimeSeries(key=apikey)

# %%
data, meta_data = ts.get_intraday('GOOGL')

# %%
data
# Out:
# {'2019-08-23 16:00:00': {'1. open': '1153.8400',
#   '2. high': '1155.8600',
#   '3. low': '1150.0600',
#   '4. close': '1153.6000',
#   '5. volume': '262926'},
#  '2019-08-23 15:45:00': {'1. open': '1155.4301',
#   '2. high': '1155.5900',
#   '3. low': '1153.6000',
#   '4. close': '1153.8300',
#   '5. volume': '91552'},
#  '2019-08-23 15:30:00': {'1. open': '1154.9600',
#   '2. high': '1157.4900',
#   '3. low': '1154.9600',
#   '4. close': '1155.7125',
#   '5. volume': '53278'},
#  '2019-08-23 15:15:00': {'1. open': '1155.3283',
#   '2. high': '1158.0500',
#   '3. low': '1154.2900',
#   '4. close': '1155.2083',
#   '5. volume': '47530'},
#  '2019-08-23 15:00:00': {'1. open': '1153.7000',
#   '2. high': '1155.2600',
#   '3. low': '1153.2200',
#   '4. close': '1155.0100',
#   '5. volume': '44978'},
#  '2019-08-23 14:45:00': {'1. open': '1156.6400',
#   '2. high': '1156.6899',
#   '3. low': '1153.2500',
#   '4. close': '1153.7200',
#   '5. volume': '35180'},
# ...

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'GOOGL',
#  '3. Last Refreshed': '2019-08-23 16:00:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
ts = TimeSeries(key=apikey,output_format='pandas', indexing_type='date')

# %%
ts

# %%
ts1 = TimeSeries(key=apikey,output_format='pandas', indexing_type='integer')

# %%
data, meta_data = ts.get_intraday(symbol='MSFT',interval='60min', outputsize='compact')

# %%
data.head()
# Out:
#                       1. open   2. high    3. low  4. close  5. volume
# date
# 2019-08-05 14:30:00  131.6499  132.5040  130.9038  131.7949  6717564.0
# 2019-08-05 15:30:00  131.7947  132.8533  131.5621  132.2048  6558160.0
# 2019-08-06 09:30:00  133.7054  135.8100  133.3476  134.3854  8993795.0
# 2019-08-06 10:30:00  134.4100  135.1400  133.7500  133.8700  3311322.0
# 2019-08-06 11:30:00  133.8835  134.3701  133.3391  133.4035  2997329.0

# %%
data, meta_data = ts1.get_intraday(symbol='MSFT',interval='60min', outputsize='compact')

# %%
data.head()
# Out:
#                   date   1. open   2. high    3. low  4. close  5. volume
# 0  2019-08-05 14:30:00  131.6499  132.5040  130.9038  131.7949  6717564.0
# 1  2019-08-05 15:30:00  131.7947  132.8533  131.5621  132.2048  6558160.0
# 2  2019-08-06 09:30:00  133.7054  135.8100  133.3476  134.3854  8993795.0
# 3  2019-08-06 10:30:00  134.4100  135.1400  133.7500  133.8700  3311322.0
# 4  2019-08-06 11:30:00  133.8835  134.3701  133.3391  133.4035  2997329.0

# %%
data, meta_data = ts.get_daily(symbol='MSFT', outputsize='compact')

# %%
data.head()
# Out:
#             1. open  2. high    3. low  4. close   5. volume
# date
# 2019-04-03   119.86   120.43  119.1500    119.97  22860700.0
# 2019-04-04   120.10   120.23  118.3800    119.36  20112800.0
# 2019-04-05   119.39   120.23  119.3700    119.89  15826200.0
# 2019-04-08   119.81   120.02  118.6400    119.93  15116200.0
# 2019-04-09   118.63   119.54  118.5774    119.28  17612000.0

# %%
data, meta_data = ts1.get_daily(symbol='MSFT', outputsize='compact')

# %%
data.head()
# Out:
#          date  1. open  2. high    3. low  4. close   5. volume
# 0  2019-04-03   119.86   120.43  119.1500    119.97  22860700.0
# 1  2019-04-04   120.10   120.23  118.3800    119.36  20112800.0
# 2  2019-04-05   119.39   120.23  119.3700    119.89  15826200.0
# 3  2019-04-08   119.81   120.02  118.6400    119.93  15116200.0
# 4  2019-04-09   118.63   119.54  118.5774    119.28  17612000.0

# %%
data = data.iloc[-1,:]

# %%
data
# Out:
# date         2019-08-23
# 1. open          137.19
# 2. high          138.35
# 3. low            132.8
# 4. close         133.39
# 5. volume    3.2524e+07
# Name: 99, dtype: object

# %%
data.to_frame()
# Out:
#                    99
# date       2019-08-23
# 1. open        137.19
# 2. high        138.35
# 3. low          132.8
# 4. close       133.39
# 5. volume  3.2524e+07

# %%
data.reset_index()
# Out:
#        index          99
# 0       date  2019-08-23
# 1    1. open      137.19
# 2    2. high      138.35
# 3     3. low       132.8
# 4   4. close      133.39
# 5  5. volume  3.2524e+07

# %%
data['symbol'] = 'MSFT'

# %%
data.T
# Out:
# date         2019-08-23
# 1. open          137.19
# 2. high          138.35
# 3. low            132.8
# 4. close         133.39
# 5. volume    3.2524e+07
# symbol             MSFT
# Name: 99, dtype: object

# %%
import pandas as pd

# %%
invst = pd.read_excel('Portfolio.xlsx')

# %%
parameters = {'given-name': 'Michael', 'number': '11111', 'currentmarketvalue': 'yes'}

# %%
fname = parameters['given-name']
currentvalue = parameters['currentmarketvalue']
folio = parameters['number']

# %%
invst['Name'] = invst['Name'].astype('category')

# %%
invst = invst[(invst['Name'].str.contains(fname, case=False)) & (invst['Folio No'] == int(folio))]

# %%
tckr = invst['Ticker'].tolist()

# %%
tckr
# Out:
# ['ADBE', 'CSCO', 'FB', 'INTC']

# %%
data,meta_data = ts1.get_batch_stock_quotes(symbols=['ADBE', 'CSCO', 'FB', 'INTC'])

# %%
data
# Out:
#    date 1. symbol  2. price 3. volume         4. timestamp
# 0     0      ADBE  288.7100        --  2019-08-26 15:59:56
# 1     1      CSCO   47.1200        --  2019-08-26 15:59:59
# 2     2        FB  180.4500        --  2019-08-26 15:59:59
# 3     3      INTC   45.5000        --  2019-08-26 15:59:57

# %%
data.rename({'2. price' : 'Current Market Price (USD)'}, axis=1, inplace=True)
data.rename({'1. symbol' : 'Ticker'}, axis=1, inplace=True)
data.rename({'4. timestamp' : 'Current Date'}, axis=1, inplace=True)

# %%
data
# Out:
#    date Ticker Current Market Price (USD) 3. volume         Current Date
# 0     0   ADBE                   288.7100        --  2019-08-26 15:59:56
# 1     1   CSCO                    47.1200        --  2019-08-26 15:59:59
# 2     2     FB                   180.4500        --  2019-08-26 15:59:59
# 3     3   INTC                    45.5000        --  2019-08-26 15:59:57

# %%
current = pd.merge(invst, data, on='Ticker', how='inner').drop(['date','3. volume'], axis=1)

# %%
current
# Out:
#    SNo           Name  Folio No            Companies Ticker  Stocks  \
# 0    1  Michael Scott     11111           Adobe Inc.   ADBE      30
# 1    2  Michael Scott     11111  Cisco Systems, Inc.   CSCO      25
# 2    3  Michael Scott     11111       Facebook, Inc.     FB      10
# 3    4  Michael Scott     11111    Intel Corporation   INTC      50
#
#   Purchase Date  Purchase Price(USD)  Investment Current Market Price (USD)  \
# 0    2018-09-20               266.47      7994.1                   288.7100
# 1    2018-09-04                47.84      1196.0                    47.1200
# 2    2018-11-30               138.26      1382.6                   180.4500
# 3    2019-05-09                47.90      2395.0                    45.5000
#
#           Current Date
# 0  2019-08-26 15:59:56
# 1  2019-08-26 15:59:59
# 2  2019-08-26 15:59:59
# 3  2019-08-26 15:59:57

# %%
current.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 12 columns):
# SNo                           4 non-null int64
# Name                          4 non-null category
# Folio No                      4 non-null int64
# Companies                     4 non-null object
# Ticker                        4 non-null object
# Stocks                        4 non-null int64
# Purchase Date                 4 non-null datetime64[ns]
# Purchase Price(USD)           4 non-null float64
# Investment                    4 non-null float64
# Current Market Price (USD)    4 non-null object
# Current Date                  4 non-null object
# Current Investment            4 non-null object
# dtypes: category(1), datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 772.0+ bytes

# %%
current['Current Market Price (USD)'] = current['Current Market Price (USD)'].astype('float')

# %%
current['Current Investment'] = current['Current Market Price (USD)'] * current['Stocks']

# %%
current
# Out:
#    SNo           Name  Folio No            Companies Ticker  Stocks  \
# 0    1  Michael Scott     11111           Adobe Inc.   ADBE      30
# 1    2  Michael Scott     11111  Cisco Systems, Inc.   CSCO      25
# 2    3  Michael Scott     11111       Facebook, Inc.     FB      10
# 3    4  Michael Scott     11111    Intel Corporation   INTC      50
#
#   Purchase Date  Purchase Price(USD)  Investment  Current Market Price (USD)  \
# 0    2018-09-20               266.47      7994.1                      288.71
# 1    2018-09-04                47.84      1196.0                       47.12
# 2    2018-11-30               138.26      1382.6                      180.45
# 3    2019-05-09                47.90      2395.0                       45.50
#
#           Current Date  Current Investment
# 0  2019-08-26 15:59:56              8661.3
# 1  2019-08-26 15:59:59              1178.0
# 2  2019-08-26 15:59:59              1804.5
# 3  2019-08-26 15:59:57              2275.0

# %%
current['Stock Performance'] = current['Current Investment'] - current['Investment']

# %%
current
# Out:
#    SNo           Name  Folio No            Companies Ticker  Stocks  \
# 0    1  Michael Scott     11111           Adobe Inc.   ADBE      30
# 1    2  Michael Scott     11111  Cisco Systems, Inc.   CSCO      25
# 2    3  Michael Scott     11111       Facebook, Inc.     FB      10
# 3    4  Michael Scott     11111    Intel Corporation   INTC      50
#
#   Purchase Date  Purchase Price(USD)  Investment  Current Market Price (USD)  \
# 0    2018-09-20               266.47      7994.1                      288.71
# 1    2018-09-04                47.84      1196.0                       47.12
# 2    2018-11-30               138.26      1382.6                      180.45
# 3    2019-05-09                47.90      2395.0                       45.50
#
#           Current Date  Current Investment  Stock Performance
# 0  2019-08-26 15:59:56              8661.3              667.2
# 1  2019-08-26 15:59:59              1178.0              -18.0
# ...

# %%
current.loc[current['Stock Performance'].idxmax()]
# Out:
# SNo                                             1
# Name                                Michael Scott
# Folio No                                    11111
# Companies                              Adobe Inc.
# Ticker                                       ADBE
# Stocks                                         30
# Purchase Date                 2018-09-20 00:00:00
# Purchase Price(USD)                        266.47
# Investment                                 7994.1
# Current Market Price (USD)                 288.71
# Current Date                  2019-08-26 15:59:56
# Current Investment                         8661.3
# Stock Performance                           667.2
# Name: 0, dtype: object

# %%
best = current[current['Stock Performance'] == current['Stock Performance'].max()]

# %%
best
# Out:
#    SNo           Name  Folio No   Companies Ticker  Stocks Purchase Date  \
# 0    1  Michael Scott     11111  Adobe Inc.   ADBE      30    2018-09-20
#
#    Purchase Price(USD)  Investment  Current Market Price (USD)  \
# 0               266.47      7994.1                      288.71
#
#           Current Date  Current Investment  Stock Performance
# 0  2019-08-26 15:59:56              8661.3              667.2

# %%
worst = current[current['Stock Performance'] == current['Stock Performance'].min()]

# %%
worst
# Out:
#    SNo           Name  Folio No          Companies Ticker  Stocks  \
# 3    4  Michael Scott     11111  Intel Corporation   INTC      50
#
#   Purchase Date  Purchase Price(USD)  Investment  Current Market Price (USD)  \
# 3    2019-05-09                 47.9      2395.0                        45.5
#
#           Current Date  Current Investment  Stock Performance
# 3  2019-08-26 15:59:57              2275.0             -120.0

# %%
 best.columns
# Out:
# Index(['SNo', 'Name', 'Folio No', 'Companies', 'Ticker', 'Stocks',
#        'Purchase Date', 'Purchase Price(USD)', 'Investment',
#        'Current Market Price (USD)', 'Current Date', 'Current Investment',
#        'Stock Performance'],
#       dtype='object')

# %%
import time
start = time.time()

# %%
tckr[3:]
# Out:
# ['INTC']

# %%
tckr
# Out:
# ['ADBE', 'CSCO', 'FB', 'INTC']

# %%
tckr[:2]
# Out:
# ['ADBE', 'CSCO']

# %%
df = pd.DataFrame()
for t in tckr[2:]:
    #data,meta_data = ts1.get_intraday(symbol=t,interval='60min', outputsize='compact')
    #data,meta_data = ts1.get_daily(symbol=t, outputsize='compact')
    data = data.iloc[-1,:]
    data['Ticker'] = t
    df = df.append(data, ignore_index=True)

# %%
end = time.time()

# %%
end-start
# Out:
# 11.713052749633789

# %%
df
# Out:
#    1. open   2. high  3. low  4. close   5. volume Ticker        date
# 0   289.23  293.5725  281.10    282.44   2377368.0   ADBE  2019-08-23
# 1    47.90   48.5150   46.43     46.61  21631370.0   CSCO  2019-08-23
# 2   180.84  183.1300  176.66    177.75  14354973.0     FB  2019-08-23
# 3    46.35   46.6300   44.80     44.96  28211515.0   INTC  2019-08-23

# %%
invst
# Out:
#    SNo           Name  Folio No            Companies Ticker  Stocks  \
# 0    1  Michael Scott     11111           Adobe Inc.   ADBE      30
# 1    2  Michael Scott     11111  Cisco Systems, Inc.   CSCO      25
# 2    3  Michael Scott     11111       Facebook, Inc.     FB      10
# 3    4  Michael Scott     11111    Intel Corporation   INTC      50
#
#   Purchase Date  Purchase Price(USD)  Investment
# 0    2018-09-20               266.47      7994.1
# 1    2018-09-04                47.84      1196.0
# 2    2018-11-30               138.26      1382.6
# 3    2019-05-09                47.90      2395.0

# %%
df.rename({'4. close' : 'Current Market Price (USD)'}, axis=1, inplace=True)
df.rename({'date' : 'Current Date'}, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['1. open', '2. high', '3. low', 'Current Market Price (USD)',
#        '5. volume', 'Ticker', 'Current Date'],
#       dtype='object')

# %%
current = pd.merge(invst, df, on='Ticker', how='inner').drop(['SNo', '1. open', '2. high', '3. low', '5. volume'], axis=1)

# %%
current
# Out:
#             Name  Folio No            Companies Ticker  Stocks Purchase Date  \
# 0  Michael Scott     11111           Adobe Inc.   ADBE      30    2018-09-20
# 1  Michael Scott     11111  Cisco Systems, Inc.   CSCO      25    2018-09-04
# 2  Michael Scott     11111       Facebook, Inc.     FB      10    2018-11-30
# 3  Michael Scott     11111    Intel Corporation   INTC      50    2019-05-09
#
#    Purchase Price(USD)  Investment  Current Market Price (USD) Current Date
# 0               266.47      7994.1                      282.44   2019-08-23
# 1                47.84      1196.0                       46.61   2019-08-23
# 2               138.26      1382.6                      177.75   2019-08-23
# 3                47.90      2395.0                       44.96   2019-08-23

# %%
current['Current Investment'] = current['Current Market Price (USD)'] * current['Stocks']

# %%
current
# Out:
#             Name  Folio No            Companies Ticker  Stocks Purchase Date  \
# 0  Michael Scott     11111           Adobe Inc.   ADBE      30    2018-09-20
# 1  Michael Scott     11111  Cisco Systems, Inc.   CSCO      25    2018-09-04
# 2  Michael Scott     11111       Facebook, Inc.     FB      10    2018-11-30
# 3  Michael Scott     11111    Intel Corporation   INTC      50    2019-05-09
#
#    Purchase Price(USD)  Investment  Current Market Price (USD) Current Date  \
# 0               266.47      7994.1                      282.44   2019-08-23
# 1                47.84      1196.0                       46.61   2019-08-23
# 2               138.26      1382.6                      177.75   2019-08-23
# 3                47.90      2395.0                       44.96   2019-08-23
#
#    Current Investment
# 0             8473.20
# 1             1165.25
# 2             1777.50
# 3             2248.00

# %%
current.columns
# Out:
# Index(['Name', 'Folio No', 'Companies', 'Ticker', 'Stocks', 'Purchase Date',
#        'Purchase Price(USD)', 'Investment', 'Current Market Price (USD)',
#        'Current Date', 'Current Investment'],
#       dtype='object')

# %%
start=time.time()

# %%
data,meta_data = ts1.get_batch_stock_quotes(symbols=['ADBE', 'CSCO', 'FB', 'INTC'])

# %%
type(data), type(meta_data)
# Out:
# (pandas.core.frame.DataFrame, dict)

# %%
data
# Out:
#    date 1. symbol  2. price 3. volume         4. timestamp
# 0     0      ADBE  288.7100        --  2019-08-26 15:59:56
# 1     1      CSCO   47.1200        --  2019-08-26 15:59:59
# 2     2        FB  180.4500        --  2019-08-26 15:59:59
# 3     3      INTC   45.5000        --  2019-08-26 15:59:57

# %%
meta_data
# Out:
# {'1. Information': 'Batch Stock Market Quotes',
#  '2. Notes': 'IEX Real-Time',
#  '3. Time Zone': 'US/Eastern'}

# %%
end=time.time()

# %%
end-start
# Out:
# 2.5023066997528076
